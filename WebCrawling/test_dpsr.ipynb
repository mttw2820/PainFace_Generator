# %%
# import

import os
import cv2
import time
import numpy as np
from math import *
import sys, traceback
from PIL import Image, ImageDraw

## web crawling
from selenium import webdriver
import urllib.request

## DPSR
from demo_test_dpsr_crawl import dpsr

## torch
import torch
import torchvision
from torchvision import models
import torchvision.transforms as T
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches

## dlib
import dlib

# %%
## test dpsr
lr_folder = "./data/test/"
after_folder = "./data/dpsr/test/"

file_list = os.listdir(lr_folder)

for file in file_list :
    dpsr(file, lr_folder, after_folder)
# Out:
# 21-04-13 15:49:54.799 : Model path DPSR_models\DPSRx4.pth. Testing...
# 21-04-13 15:49:54.799 : ./data/test/
# LogHandlers exists!
# 21-04-13 15:49:54.940 : Iter: ---1--> childbirth_2.jpeg
# 21-04-13 15:49:55.033 : Iter: ---2--> childbirth_2.jpeg
# 21-04-13 15:49:55.190 : Iter: ---3--> childbirth_2.jpeg
# 21-04-13 15:49:55.330 : Iter: ---4--> childbirth_2.jpeg
# 21-04-13 15:49:55.486 : Iter: ---5--> childbirth_2.jpeg
# 21-04-13 15:49:55.768 : saving: sf = 4, childbirth_2_x4.jpeg.
